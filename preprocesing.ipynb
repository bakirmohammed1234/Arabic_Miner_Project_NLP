# %%
import pandas as pd

# %%
df = pd.read_csv("DataSets/arabic_dataset_classifiction.csv/arabic_dataset_classifiction.csv")

# %%
df = pd.read_csv("DataSets/text.txt")

# %%
df.columns
# Out:
# Index(['text', 'targe'], dtype='object')

# %%
df.drop(columns=["targe"], inplace=True)

# %%
df.shape
# Out:
# (111728, 1)

# %%
# Sauvegarder en fichier TXT
df.to_csv("DataSets/text.txt", index=False, sep='\t')
